# %% [markdown]
# ![image.png](attachment:ba6ef6e8-bb8d-4176-a1ec-e93acb3ea262.png)

# %%
#ans1
#Flask is a lightweight and micro web framework for Python. It is designed to be simple, flexible, 
# and easy to use, making it an excellent choice for building web applications and APIs.
#advantages:
#Simple
#flexable
#efficient

#ans2
from flask import Flask
app = Flask(__name__)

@app.route("/")
def hello_world():
    return "<h1>Hello, World!</h1>"



@app.route("/welcome")
def fun1():
    A= "company: abc corporation"
    b="Location: India"
    c="Contact Detail: 999-999-9999"
    return f"Welcome to the ABC corporation {b} and {c}"

if __name__=="__main__":
    app.run(host="0.0.0.0")


#ans3
#In Flask, app routing refers to the process of defining URL routes and mapping them to 
#specific functions or view handlers in your web application. Routes determine how different 
#URLs are handled by the application,
#specifying which code should be executed when a particular URL is accessed
