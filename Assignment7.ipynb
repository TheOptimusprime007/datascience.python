# %%
#Answer1

#exception is an error that occurs during excution of a program. When that error occurs, 
#python generate an exception that can be handled, which avoids your program to crash.

#syntax error is a error that occurs when python parser detects a syntax error.

#Answer2
#when exception is not handled , the program will crash and the exception will be printed.

try:
    a=10
    b=0
    print(a/b) #exception occurs here
finally:
    print("program over")
#answer3
#exceptions are handled by try and except block.


try:
    a1=10
    b1=0
    print(a1/b1)
except Exception as e:
    print("exception occured",e)

finally:
    print("out of the program")


#answer4
try:
    a2=int(input("enter a number"))
    print(a2)

except Exception as e:
    print("Exception occurred:", e)

else:
    print("no exception occured")

finally:
    print("out of the program")

#raise is used to throw an exception when a certain condition is not met.
age=int(input("enter age"))
if age<18:
    raise Exception("age should be above 18")


#answer5
#custom exception is used to create our own exception.
age=int(input("enter age"))
if age<18:
    raise Exception("age should be above 18") #custom exception
finally:
    print("out of the program")

#answer6
#exception class is the base class for all the exceptions in python.
#exception class is used to handle all the exceptions.

password = input("Enter password: ")

class Pass1Exception(Exception):
    def __init__(self, msg):
        self.msg = msg

def checkpassword(password):
   
    
    if len(password) < 8:
        raise Pass1Exception("Password is invalid")
        
        if password.count("@") + password.count("#") + password.count("$") + password.count("&") < 2:
            raise Pass1Exception("Password is valid")

try:
    checkpassword(password)
except Pass1Exception as e:
    print(e)
