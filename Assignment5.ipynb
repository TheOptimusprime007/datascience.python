# %%
#answer1
# a class is a blueprint for creating objects
# an object is an instance of a class
class a:
   print("inside class a")
   b=10;

obj1=a()#creating object of class a
print(obj1.b)

        
#answer2
# four pillars of oops are inheritance, polymorphism, abstraction, encapsulation
# inheritance is the process by which one class acquires the properties of another class
# polymorphism is the ability to take various forms
# abstraction is the process of hiding the internal details and showing the functionality
# encapsulation is the process of binding the data and the functions acting on the data together as a single unit

#answer3
#__init__ is a constructor method which is used to initialize the instance members of a class
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

# Creating instances of the Person class
person1 = Person("Alice", 30)
person2 = Person("Bob", 25)

print(person1.name, person1.age)  
print(person2.name, person2.age) 

#answer4
#self is a keyword which is used to represent the instance of the class
#self is used to access the instance variables and methods of a class
#self is used to pass the values of instance variables to the methods of a class
class Person:
      def __init__(self, name, age):
         self.name = name
         self.age = age
   
      def my_function(self):
         print("Hello my name is " + self.name)

p1 = Person("John", 36)
p1.my_function()

#answer5
#heritance is when we can use the ojects of parent class with the child class
#single interitance 
class parent:
    def test(self):
        print("this is the parent class")
        a=10;

class child(parent):
    def test(self):
         print("this is the child class")
         b=20;

obj=child()
obj.test()
obj.test()

#mutilevel inheritance
class parent1:
    def test1(self):
        print("this is the parent class")
a1=10;

class child2(parent1):
    def test2(self):
         print("this is the child class")

b1=20;

class child3(child2):
      def test3(self):
            print("this is the child class")
            c=a1+b1;
            print(c);

obj=child3()
obj.test3()
obj.test2()
obj.test1()

#multiple inheritance
class a:
      def test4(self):
         print("this is the parent1 class")
m=10;

class b:
      def test5(self):
         print("this is the parent2 class")
n=40;

class c(a,b):
      def test6(self):
         print("this is the child class")
      l=n+m;
      print(l);

obj=c()
obj.test4()
obj.test5()
obj.test6()
# Out:
# inside class a
# 10
# Alice 30
# Bob 25
# Hello my name is John
# this is the child class
# this is the child class
# this is the child class
# 30
# this is the child class
# this is the parent class
# 50
# this is the parent1 class
# this is the parent2 class
# this is the child class
